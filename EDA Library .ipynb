# %%
# D-Tale
# !pip install dtale
# Out:
# Collecting dtale
#   Downloading dtale-1.43.0-py2.py3-none-any.whl (14.4 MB)
# Collecting statsmodels; python_version > "3.0"
#   Downloading statsmodels-0.12.2-cp39-none-win_amd64.whl (9.4 MB)
# Collecting openpyxl; python_version >= "3.0"
#   Downloading openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
# Collecting networkx; python_version >= "3.0"
#   Downloading networkx-2.5.1-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: pandas in c:\py_env\jupyter_base\lib\site-packages (from dtale) (1.2.3)
# Collecting dash>=1.5.0
#   Downloading dash-1.20.0.tar.gz (77 kB)
# Requirement already satisfied: scikit-learn in c:\py_env\jupyter_base\lib\site-packages (from dtale) (0.24.1)
# Collecting strsimpy
#   Downloading strsimpy-0.2.0-py3-none-any.whl (45 kB)
# Collecting requests
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting dash-bootstrap-components; python_version > "3.0"
#   Downloading dash_bootstrap_components-0.12.0-py3-none-any.whl (191 kB)
# Collecting Flask-Compress
#   Downloading Flask_Compress-1.9.0-py3-none-any.whl (7.3 kB)
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Collecting future>=0.14.0
#   Downloading future-0.18.2.tar.gz (829 kB)
# Requirement already satisfied: scipy in c:\py_env\jupyter_base\lib\site-packages (from dtale) (1.6.2)
# Collecting flask-ngrok; python_version > "3.0"
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Collecting lz4; python_version > "3.0"
#   Downloading lz4-3.1.3-cp39-cp39-win_amd64.whl (192 kB)
# Collecting itsdangerous
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting dash-colorscales
#   Downloading dash_colorscales-0.0.4.tar.gz (62 kB)
# Requirement already satisfied: six in c:\py_env\jupyter_base\lib\site-packages (from dtale) (1.15.0)
# Collecting xarray; python_version >= "3.0"
#   Downloading xarray-0.17.0-py3-none-any.whl (759 kB)
# Requirement already satisfied: seaborn; python_version >= "3.6" in c:\py_env\jupyter_base\lib\site-packages (from dtale) (0.11.1)
# Collecting missingno
#   Downloading missingno-0.4.2-py3-none-any.whl (9.7 kB)
# Collecting dash-daq
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
# Collecting Flask>=1.0
#   Downloading Flask-1.1.2-py2.py3-none-any.whl (94 kB)
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Requirement already satisfied: plotly>=4.9.0 in c:\py_env\jupyter_base\lib\site-packages (from dtale) (4.14.3)
# Collecting ppscore; python_version >= "3.6"
#   Downloading ppscore-1.2.0.tar.gz (47 kB)
# Collecting kaleido; python_version > "3.6"
#   Downloading kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9 MB)
# Requirement already satisfied: numpy>=1.15 in c:\py_env\jupyter_base\lib\site-packages (from statsmodels; python_version > "3.0"->dtale) (1.20.2)
# Collecting patsy>=0.5
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.0.1.tar.gz (8.4 kB)
# Requirement already satisfied: decorator<5,>=4.3 in c:\py_env\jupyter_base\lib\site-packages (from networkx; python_version >= "3.0"->dtale) (4.4.2)
# Requirement already satisfied: pytz>=2017.3 in c:\py_env\jupyter_base\lib\site-packages (from pandas->dtale) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\py_env\jupyter_base\lib\site-packages (from pandas->dtale) (2.8.1)
# Collecting dash_renderer==1.9.1
#   Downloading dash_renderer-1.9.1.tar.gz (1.0 MB)
# Collecting dash-core-components==1.16.0
#   Downloading dash_core_components-1.16.0.tar.gz (3.5 MB)
# Collecting dash-html-components==1.1.3
#   Downloading dash_html_components-1.1.3.tar.gz (82 kB)
# Collecting dash-table==4.11.3
#   Downloading dash_table-4.11.3.tar.gz (1.8 MB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\py_env\jupyter_base\lib\site-packages (from scikit-learn->dtale) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\py_env\jupyter_base\lib\site-packages (from scikit-learn->dtale) (1.0.1)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\py_env\jupyter_base\scripts\python.exe -m pip install --upgrade pip' command.
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2020.12.5-py2.py3-none-any.whl (147 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp39-cp39-win_amd64.whl (383 kB)
# Requirement already satisfied: setuptools>=40.4 in c:\py_env\jupyter_base\lib\site-packages (from xarray; python_version >= "3.0"->dtale) (49.2.1)
# Requirement already satisfied: matplotlib>=2.2 in c:\py_env\jupyter_base\lib\site-packages (from seaborn; python_version >= "3.6"->dtale) (3.4.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\py_env\jupyter_base\lib\site-packages (from Flask>=1.0->dtale) (2.11.3)
# Collecting Werkzeug>=0.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied: retrying>=1.3.3 in c:\py_env\jupyter_base\lib\site-packages (from plotly>=4.9.0->dtale) (1.3.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\py_env\jupyter_base\lib\site-packages (from matplotlib>=2.2->seaborn; python_version >= "3.6"->dtale) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\py_env\jupyter_base\lib\site-packages (from matplotlib>=2.2->seaborn; python_version >= "3.6"->dtale) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\py_env\jupyter_base\lib\site-packages (from matplotlib>=2.2->seaborn; python_version >= "3.6"->dtale) (8.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\py_env\jupyter_base\lib\site-packages (from matplotlib>=2.2->seaborn; python_version >= "3.6"->dtale) (1.3.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\py_env\jupyter_base\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0->dtale) (1.1.1)
# Using legacy 'setup.py install' for dash, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for future, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for dash-colorscales, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for dash-daq, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for ppscore, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for et-xmlfile, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for dash-renderer, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for dash-core-components, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for dash-html-components, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for dash-table, since package 'wheel' is not installed.
# Installing collected packages: patsy, statsmodels, et-xmlfile, openpyxl, networkx, Werkzeug, click, itsdangerous, Flask, brotli, Flask-Compress, dash-renderer, dash-core-components, dash-html-components, dash-table, future, dash, strsimpy, idna, urllib3, certifi, chardet, requests, dash-bootstrap-components, squarify, flask-ngrok, lz4, dash-colorscales, xarray, missingno, dash-daq, xlrd, ppscore, kaleido, dtale
#     Running setup.py install for et-xmlfile: started
#     Running setup.py install for et-xmlfile: finished with status 'done'
#     Running setup.py install for dash-renderer: started
#     Running setup.py install for dash-renderer: finished with status 'done'
#     Running setup.py install for dash-core-components: started
#     Running setup.py install for dash-core-components: finished with status 'done'
#     Running setup.py install for dash-html-components: started
#     Running setup.py install for dash-html-components: finished with status 'done'
#     Running setup.py install for dash-table: started
#     Running setup.py install for dash-table: finished with status 'done'
#     Running setup.py install for future: started
#     Running setup.py install for future: finished with status 'done'
#     Running setup.py install for dash: started
#     Running setup.py install for dash: finished with status 'done'
#     Running setup.py install for dash-colorscales: started
#     Running setup.py install for dash-colorscales: finished with status 'done'
#     Running setup.py install for dash-daq: started
#     Running setup.py install for dash-daq: finished with status 'done'
#     Running setup.py install for ppscore: started
#     Running setup.py install for ppscore: finished with status 'done'
# Successfully installed Flask-1.1.2 Flask-Compress-1.9.0 Werkzeug-1.0.1 brotli-1.0.9 certifi-2020.12.5 chardet-4.0.0 click-7.1.2 dash-1.20.0 dash-bootstrap-components-0.12.0 dash-colorscales-0.0.4 dash-core-components-1.16.0 dash-daq-0.5.0 dash-html-components-1.1.3 dash-renderer-1.9.1 dash-table-4.11.3 dtale-1.43.0 et-xmlfile-1.0.1 flask-ngrok-0.0.25 future-0.18.2 idna-2.10 itsdangerous-1.1.0 kaleido-0.2.1 lz4-3.1.3 missingno-0.4.2 networkx-2.5.1 openpyxl-3.0.7 patsy-0.5.1 ppscore-1.2.0 requests-2.25.1 squarify-0.4.3 statsmodels-0.12.2 strsimpy-0.2.0 urllib3-1.26.4 xarray-0.17.0 xlrd-2.0.1

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\py_env\jupyter_base\lib\site-packages (0.11.1)
# Requirement already satisfied: numpy>=1.15 in c:\py_env\jupyter_base\lib\site-packages (from seaborn) (1.20.2)
# Requirement already satisfied: scipy>=1.0 in c:\py_env\jupyter_base\lib\site-packages (from seaborn) (1.6.2)
# Requirement already satisfied: pandas>=0.23 in c:\py_env\jupyter_base\lib\site-packages (from seaborn) (1.2.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\py_env\jupyter_base\lib\site-packages (from seaborn) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\py_env\jupyter_base\lib\site-packages (from pandas>=0.23->seaborn) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\py_env\jupyter_base\lib\site-packages (from pandas>=0.23->seaborn) (2021.1)
# Requirement already satisfied: cycler>=0.10 in c:\py_env\jupyter_base\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\py_env\jupyter_base\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\py_env\jupyter_base\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\py_env\jupyter_base\lib\site-packages (from matplotlib>=2.2->seaborn) (8.1.2)
# Requirement already satisfied: six>=1.5 in c:\py_env\jupyter_base\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->seaborn) (1.15.0)
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\py_env\jupyter_base\scripts\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns
df=sns.load_dataset('titanic')

# %%
df.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import dtale
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-EOH3007A:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# c:\py_env\jupyter_base\lib\site-packages\pandas\plotting\_matplotlib\tools.py:400: MatplotlibDeprecationWarning:
#
#
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\py_env\jupyter_base\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\py_env\jupyter_base\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\py_env\jupyter_base\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\py_env\jupyter_base\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\py_env\jupyter_base\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\py_env\jupyter_base\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\py_env\jupyter_base\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "c:\py_env\jupyter_base\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\py_env\jupyter_base\lib\site-packages\dtale\dash_application\views.py", line 1109, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "c:\py_env\jupyter_base\lib\site-packages\dtale\dash_application\layout\layout.py", line 989, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "c:\py_env\jupyter_base\lib\site-packages\dtale\charts\utils.py", line 964, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "c:\py_env\jupyter_base\lib\site-packages\dtale\charts\utils.py", line 328, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "c:\py_env\jupyter_base\lib\site-packages\pandas\core\reshape\concat.py", line 285, in concat
#     op = _Concatenator(
#   File "c:\py_env\jupyter_base\lib\site-packages\pandas\core\reshape\concat.py", line 342, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# 2021-04-21 10:35:24,696 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\py_env\jupyter_base\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\py_env\jupyter_base\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\py_env\jupyter_base\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\py_env\jupyter_base\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\py_env\jupyter_base\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\py_env\jupyter_base\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\py_env\jupyter_base\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "c:\py_env\jupyter_base\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\py_env\jupyter_base\lib\site-packages\dtale\dash_application\views.py", line 1109, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "c:\py_env\jupyter_base\lib\site-packages\dtale\dash_application\layout\layout.py", line 989, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "c:\py_env\jupyter_base\lib\site-packages\dtale\charts\utils.py", line 964, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "c:\py_env\jupyter_base\lib\site-packages\dtale\charts\utils.py", line 328, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "c:\py_env\jupyter_base\lib\site-packages\pandas\core\reshape\concat.py", line 285, in concat
#     op = _Concatenator(
#   File "c:\py_env\jupyter_base\lib\site-packages\pandas\core\reshape\concat.py", line 342, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate

# %%
# !pip install pandas-profiling
# Out:
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\py_env\jupyter_base\scripts\python.exe -m pip install --upgrade pip' command.
# Collecting pandas-profiling
#   Downloading pandas_profiling-2.11.0-py2.py3-none-any.whl (243 kB)
# Collecting confuse>=1.0.0
#   Downloading confuse-1.4.0-py2.py3-none-any.whl (21 kB)
# Collecting tangled-up-in-unicode>=0.0.6
#   Downloading tangled_up_in_unicode-0.0.7-py3-none-any.whl (3.1 MB)
# Requirement already satisfied: joblib in c:\py_env\jupyter_base\lib\site-packages (from pandas-profiling) (1.0.1)
# Collecting tqdm>=4.48.2
#   Downloading tqdm-4.60.0-py2.py3-none-any.whl (75 kB)
# Requirement already satisfied: seaborn>=0.10.1 in c:\py_env\jupyter_base\lib\site-packages (from pandas-profiling) (0.11.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\py_env\jupyter_base\lib\site-packages (from pandas-profiling) (2.11.3)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\py_env\jupyter_base\lib\site-packages (from pandas-profiling) (7.6.3)
# Collecting phik>=0.10.0
#   Downloading phik-0.11.2.tar.gz (1.1 MB)
# Requirement already satisfied: scipy>=1.4.1 in c:\py_env\jupyter_base\lib\site-packages (from pandas-profiling) (1.6.2)
# Collecting htmlmin>=0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\py_env\jupyter_base\lib\site-packages (from pandas-profiling) (1.2.3)
# Requirement already satisfied: requests>=2.24.0 in c:\py_env\jupyter_base\lib\site-packages (from pandas-profiling) (2.25.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\py_env\jupyter_base\lib\site-packages (from pandas-profiling) (1.20.2)
# Requirement already satisfied: missingno>=0.4.2 in c:\py_env\jupyter_base\lib\site-packages (from pandas-profiling) (0.4.2)
# Requirement already satisfied: attrs>=19.3.0 in c:\py_env\jupyter_base\lib\site-packages (from pandas-profiling) (20.3.0)
# Collecting visions[type_image_path]==0.6.0
#   Downloading visions-0.6.0-py3-none-any.whl (75 kB)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\py_env\jupyter_base\lib\site-packages (from pandas-profiling) (3.4.0)
# Collecting pyyaml
#   Downloading PyYAML-5.4.1-cp39-cp39-win_amd64.whl (213 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\py_env\jupyter_base\lib\site-packages (from jinja2>=2.11.1->pandas-profiling) (1.1.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\py_env\jupyter_base\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (5.1.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\py_env\jupyter_base\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (5.5.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\py_env\jupyter_base\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in c:\py_env\jupyter_base\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (1.0.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\py_env\jupyter_base\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (5.0.5)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in c:\py_env\jupyter_base\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (7.22.0)
# Requirement already satisfied: pytz>=2017.3 in c:\py_env\jupyter_base\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\py_env\jupyter_base\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\py_env\jupyter_base\lib\site-packages (from requests>=2.24.0->pandas-profiling) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\py_env\jupyter_base\lib\site-packages (from requests>=2.24.0->pandas-profiling) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\py_env\jupyter_base\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\py_env\jupyter_base\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2020.12.5)
# Requirement already satisfied: networkx>=2.4 in c:\py_env\jupyter_base\lib\site-packages (from visions[type_image_path]==0.6.0->pandas-profiling) (2.5.1)
# Requirement already satisfied: Pillow; extra == "type_image_path" in c:\py_env\jupyter_base\lib\site-packages (from visions[type_image_path]==0.6.0->pandas-profiling) (8.1.2)
# Collecting imagehash; extra == "type_image_path"
#   Downloading ImageHash-4.2.0-py2.py3-none-any.whl (295 kB)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\py_env\jupyter_base\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\py_env\jupyter_base\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\py_env\jupyter_base\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.10.0)
# Requirement already satisfied: jupyter-core in c:\py_env\jupyter_base\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\py_env\jupyter_base\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (3.2.0)
# Requirement already satisfied: ipython-genutils in c:\py_env\jupyter_base\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (0.2.0)
# Requirement already satisfied: tornado>=4.2 in c:\py_env\jupyter_base\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling) (6.1)
# Requirement already satisfied: jupyter-client in c:\py_env\jupyter_base\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling) (6.1.12)
# Requirement already satisfied: notebook>=4.4.1 in c:\py_env\jupyter_base\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (6.3.0)
# Requirement already satisfied: backcall in c:\py_env\jupyter_base\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.2.0)
# Requirement already satisfied: decorator in c:\py_env\jupyter_base\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (4.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\py_env\jupyter_base\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (3.0.18)
# Requirement already satisfied: setuptools>=18.5 in c:\py_env\jupyter_base\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (49.2.1)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\py_env\jupyter_base\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.4.4)
# Requirement already satisfied: pickleshare in c:\py_env\jupyter_base\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.7.5)
# Requirement already satisfied: pygments in c:\py_env\jupyter_base\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (2.8.1)
# Requirement already satisfied: jedi>=0.16 in c:\py_env\jupyter_base\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\py_env\jupyter_base\lib\site-packages (from python-dateutil>=2.7.3->pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (1.15.0)
# Collecting PyWavelets
#   Downloading PyWavelets-1.1.1-cp39-cp39-win_amd64.whl (4.2 MB)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\py_env\jupyter_base\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (300)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\py_env\jupyter_base\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (0.17.3)
# Requirement already satisfied: pyzmq>=13 in c:\py_env\jupyter_base\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling) (22.0.3)
# Requirement already satisfied: argon2-cffi in c:\py_env\jupyter_base\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (20.1.0)
# Requirement already satisfied: nbconvert in c:\py_env\jupyter_base\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (6.0.7)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\py_env\jupyter_base\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\py_env\jupyter_base\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.9.3)
# Requirement already satisfied: prometheus-client in c:\py_env\jupyter_base\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.9.0)
# Requirement already satisfied: wcwidth in c:\py_env\jupyter_base\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\py_env\jupyter_base\lib\site-packages (from jedi>=0.16->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.8.1)
# Requirement already satisfied: cffi>=1.0.0 in c:\py_env\jupyter_base\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.14.5)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\py_env\jupyter_base\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.5.3)
# Requirement already satisfied: defusedxml in c:\py_env\jupyter_base\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\py_env\jupyter_base\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\py_env\jupyter_base\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in c:\py_env\jupyter_base\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\py_env\jupyter_base\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.3)
# Requirement already satisfied: bleach in c:\py_env\jupyter_base\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (3.3.0)
# Requirement already satisfied: testpath in c:\py_env\jupyter_base\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.4.4)
# Requirement already satisfied: pywinpty>=0.5; os_name == "nt" in c:\py_env\jupyter_base\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.5.7)
# Requirement already satisfied: pycparser in c:\py_env\jupyter_base\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (2.20)
# Requirement already satisfied: nest-asyncio in c:\py_env\jupyter_base\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.5.1)
# Requirement already satisfied: async-generator in c:\py_env\jupyter_base\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.10)
# Requirement already satisfied: packaging in c:\py_env\jupyter_base\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (20.9)
# Requirement already satisfied: webencodings in c:\py_env\jupyter_base\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.5.1)
# Using legacy 'setup.py install' for phik, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for htmlmin, since package 'wheel' is not installed.
# Installing collected packages: pyyaml, confuse, tangled-up-in-unicode, tqdm, phik, htmlmin, PyWavelets, imagehash, visions, pandas-profiling
#     Running setup.py install for phik: started
#     Running setup.py install for phik: finished with status 'done'
#     Running setup.py install for htmlmin: started
#     Running setup.py install for htmlmin: finished with status 'done'
# Successfully installed PyWavelets-1.1.1 confuse-1.4.0 htmlmin-0.1.12 imagehash-4.2.0 pandas-profiling-2.11.0 phik-0.11.2 pyyaml-5.4.1 tangled-up-in-unicode-0.0.7 tqdm-4.60.0 visions-0.6.0

# %%
# pandas profiling
import seaborn as sns
df_1=sns.load_dataset('tips')

# %%
from pandas_profiling import ProfileReport
profile=ProfileReport(df_1,explorative=True)
profile.to_file('output.html')
# Out:
# Summarize dataset:   0%|          | 0/20 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install sweetviz
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.1.0-py3-none-any.whl (15.1 MB)
# Requirement already satisfied: jinja2>=2.11.1 in c:\py_env\jupyter_base\lib\site-packages (from sweetviz) (2.11.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\py_env\jupyter_base\lib\site-packages (from sweetviz) (1.2.3)
# Requirement already satisfied: numpy>=1.16.0 in c:\py_env\jupyter_base\lib\site-packages (from sweetviz) (1.20.2)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\py_env\jupyter_base\lib\site-packages (from sweetviz) (3.4.0)
# Collecting importlib-resources>=1.2.0
#   Downloading importlib_resources-5.1.2-py3-none-any.whl (25 kB)
# Requirement already satisfied: scipy>=1.3.2 in c:\py_env\jupyter_base\lib\site-packages (from sweetviz) (1.6.2)
# Requirement already satisfied: tqdm>=4.43.0 in c:\py_env\jupyter_base\lib\site-packages (from sweetviz) (4.60.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\py_env\jupyter_base\lib\site-packages (from jinja2>=2.11.1->sweetviz) (1.1.1)
# Requirement already satisfied: pytz>=2017.3 in c:\py_env\jupyter_base\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\py_env\jupyter_base\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\py_env\jupyter_base\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\py_env\jupyter_base\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (8.1.2)
# Requirement already satisfied: cycler>=0.10 in c:\py_env\jupyter_base\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\py_env\jupyter_base\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.4.7)
# Requirement already satisfied: six>=1.5 in c:\py_env\jupyter_base\lib\site-packages (from python-dateutil>=2.7.3->pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (1.15.0)
# Installing collected packages: importlib-resources, sweetviz
# Successfully installed importlib-resources-5.1.2 sweetviz-2.1.0
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\py_env\jupyter_base\scripts\python.exe -m pip install --upgrade pip' command.

# %%
#sweetviz
import sweetviz as sv
report=sv.analyze(df)
report.show_html('sweet_report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report sweet_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
#autoviz
